# %%
#To find all class-containing ontology graphs 
#Max Rows by default: 10 (this can be changed)
%endpoint http://sparql.bioontology.org/sparql
%display table
%qparam apikey f9367108-21b4-4554-aa43-dee8fb7ccaea                             

%show all

# %%
%endpoint http://sparql.bioontology.org/sparql
%display table
%qparam apikey f9367108-21b4-4554-aa43-dee8fb7ccaea                             

%show all

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT DISTINCT ?super_substance_label ?substance ?substance_label
WHERE 
{
    {
        ?substance rdfs:subClassOf snomed-term:105590001 .
        snomed-term:105590001 skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 . 
        ?substance rdfs:subClassOf ?a.      
        ?a skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 . 
        ?b rdfs:subClassOf ?a .
        ?substance rdfs:subClassOf ?b .
        ?b skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?substance rdfs:subClassOf ?c .
        ?c skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?substance rdfs:subClassOf ?d .
        ?d skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?e rdfs:subClassOf ?d .
        ?substance rdfs:subClassOf ?e .
        ?e skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:105590001 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?e rdfs:subClassOf ?d .
        ?f rdfs:subClassOf ?e .
        ?substance rdfs:subClassOf ?f .
        ?f skos:altLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    FILTER regex(lcase(str(?substance_label)), "dipyron")
} limit 1000
# Out:
# Endpoint set to: http://sparql.bioontology.org/sparql
# Display: table
# Param set: apikey = f9367108-21b4-4554-aa43-dee8fb7ccaea
# Result maximum size: unlimited
# <div class="krn-spql"><table><tr class=hdr><th>super_substance_label</th>
# <th>substance</th>
# <th>substance_label</th></tr><tr class=odd><td class=val>Pyrazole derivative anti-inflammatory agent (substance)</td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/22165008" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/22165008</a></td>
# <td class=val>Dipyrone (substance)</td></tr></table><div class="tinfo">Total: 1, Shown: 1</div></div>

# %%
%endpoint http://sparql.bioontology.org/sparql
%display table
%qparam apikey fernando

%show all

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT DISTINCT ?super_substance_label ?substance ?substance_label
WHERE 
{
    {
        ?substance rdfs:subClassOf snomed-term:373873005 .
        snomed-term:373873005 skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 . 
        ?substance rdfs:subClassOf ?a.      
        ?a skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 . 
        ?b rdfs:subClassOf ?a .
        ?substance rdfs:subClassOf ?b .
        ?b skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?substance rdfs:subClassOf ?c .
        ?c skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?substance rdfs:subClassOf ?d .
        ?d skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?e rdfs:subClassOf ?d .
        ?substance rdfs:subClassOf ?e .
        ?e skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    union
    {
        ?a rdfs:subClassOf snomed-term:373873005 .
        ?b rdfs:subClassOf ?a .
        ?c rdfs:subClassOf ?b .
        ?d rdfs:subClassOf ?c .
        ?e rdfs:subClassOf ?d .
        ?f rdfs:subClassOf ?e .
        ?substance rdfs:subClassOf ?f .
        ?f skos:prefLabel ?super_substance_label .
        ?substance skos:altLabel ?substance_label.
    }
    FILTER (regex(lcase(str(?substance_label)), "penicillin") || regex(lcase(str(?substance_label)), "paracetamol"))
} limit 1000
# Out:
# Endpoint set to: http://sparql.bioontology.org/sparql
# Display: table
# Param set: apikey = fernando
# Result maximum size: unlimited
# <div class="krn-spql"><table><tr class=hdr><th>super_substance_label</th>
# <th>substance</th>
# <th>substance_label</th></tr><tr class=odd><td class=val>Oral form paracetamol</td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/421788003" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/421788003</a></td>
# <td class=val>Paracetamol 300mg/oxycodone 2.5mg tablet</td></tr><tr class=even><td class=val>Oral form paracetamol</td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/377381003" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/377381003</a></td>
# <td class=val>Paracetamol + phenyltoloxamine citrate + salicylamide 300mg/20mg/200mg capsule</td></tr><tr class=odd><td class=val>Oral form paracetamol</td>
# ...

# %%
%endpoint http://sparql.bioontology.org/sparql
%display table
%qparam apikey f9367108-21b4-4554-aa43-dee8fb7ccaea                             

%show all

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT DISTINCT ?substance_label ?substance ?ingredient ?ingredient_label
WHERE 
{
    {
        ?substance <http://purl.bioontology.org/ontology/SNOMEDCT/has_active_ingredient> ?ingredient .
        ?ingredient skos:altLabel ?ingredient_label .
        ?substance skos:altLabel ?substance_label.
    }
    FILTER regex(lcase(str(?ingredient_label)), "dipy")
} limit 1000
# Out:
# Endpoint set to: http://sparql.bioontology.org/sparql
# Display: table
# Param set: apikey = f9367108-21b4-4554-aa43-dee8fb7ccaea
# Result maximum size: unlimited
# <div class="krn-spql"><table><tr class=hdr><th>substance_label</th>
# <th>substance</th>
# <th>ingredient</th>
# <th>ingredient_label</th></tr><tr class=odd><td class=val>Dipyridamole 50mg/5mL oral suspension (product)</td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/407826005" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/407826005</a></td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/387371005" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/387371005</a></td>
# <td class=val>Dipyridamole (substance)</td></tr><tr class=even><td class=val>Dipyridamole 100mg tablet (product)</td>
# <td class=val><a href="http://purl.bioontology.org/ontology/SNOMEDCT/319759002" target="_other">http://purl.bioontology.org/ontology/SNOMEDCT/319759002</a></td>
# ...

# %%
%endpoint http://sparql.bioontology.org/sparql
%display table
%qparam apikey f9367108-21b4-4554-aa43-dee8fb7ccaea                             

%show all

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

select distinct ?property ?obj where {
    <http://purl.bioontology.org/ontology/SNOMEDCT/22165008>  ?property ?obj .
    
}
# Out:
# Endpoint set to: http://sparql.bioontology.org/sparql
# Display: table
# Param set: apikey = f9367108-21b4-4554-aa43-dee8fb7ccaea
# Result maximum size: unlimited
# <div class="krn-spql"><table><tr class=hdr><th>property</th>
# <th>obj</th></tr><tr class=odd><td class=val><a href="http://bioportal.bioontology.org/ontologies/umls/hasSTY" target="_other">http://bioportal.bioontology.org/ontologies/umls/hasSTY</a></td>
# <td class=val><a href="http://bioportal.bioontology.org/ontologies/umls/sty/T109" target="_other">http://bioportal.bioontology.org/ontologies/umls/sty/T109</a></td></tr><tr class=even><td class=val><a href="http://bioportal.bioontology.org/ontologies/umls/hasSTY" target="_other">http://bioportal.bioontology.org/ontologies/umls/hasSTY</a></td>
# ...

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT DISTINCT ?allergy_label ?allergy ?allergenic ?allergenic_label
WHERE
{   
    {
        ?allergy rdfs:subClassOf snomed-term:410942007 .
        ?allergy skos:prefLabel ?allergy_label .
        
        ?allergenic skos:prefLabel ?allergenic_label.
    }
    union
    {
        ?allergy rdfs:subClassOf ?a.
        ?a rdfs:subClassOf snomed-term:410942007 .
        
        ?allergy skos:prefLabel ?allergy_label .
        ?allergenic skos:prefLabel ?allergenic_label.
    }
    union
    {
        ?allergy rdfs:subClassOf ?b .
        ?b rdfs:subClassOf ?a .
        ?a rdfs:subClassOf snomed-term:410942007 .
        
        ?allergy skos:prefLabel ?allergy_label .
        ?allergenic skos:prefLabel ?allergenic_label.
    }
    union
    {
        ?allergy rdfs:subClassOf ?c .
        ?c rdfs:subClassOf ?b .
        ?b rdfs:subClassOf ?a .
        ?a rdfs:subClassOf snomed-term:410942007 .
        
        ?allergy skos:prefLabel ?allergy_label .
        ?allergenic skos:prefLabel ?allergenic_label.
    }
    union
    {
        ?allergy rdfs:subClassOf ?d .
        ?d rdfs:subClassOf ?c .
        ?c rdfs:subClassOf ?b .
        ?b rdfs:subClassOf ?a .
        ?a rdfs:subClassOf snomed-term:410942007 .
        
        ?allergy skos:prefLabel ?allergy_label .
        ?allergenic skos:prefLabel ?allergenic_label.
    }
    union
    {
        ?allergy rdfs:subClassOf ?e .
        ?e rdfs:subClassOf ?d .
        ?d rdfs:subClassOf ?c .
        ?c rdfs:subClassOf ?b .
        ?b rdfs:subClassOf ?a .
        ?a rdfs:subClassOf snomed-term:410942007 .
        
        ?allergy skos:prefLabel ?allergy_label .
        ?allergenic skos:prefLabel ?allergenic_label.
    }
}

# %%
select distinct ?property where {
    service <http://sparql.bioontology.org/sparql>
    {
        ?instance ?property ?obj . 
    }
    service <http://localhost:8890/sparql>
    {
        ?instance ?property ?obj . 
    } 
}

# %%
select distinct ?property where {
    service <http://sparql.bioontology.org/sparql>
    {
        ?instance ?property ?obj . 
    }
    service <http://localhost:8890/sparql>
    {
        ?instance ?property ?obj . 
    } 
    FILTER regex(str(?label), "llerg")
}

# %%
PREFIX meta: <http://bioportal.bioontology.org/metadata/def/>

SELECT DISTINCT ?vrtID ?graph
WHERE {
    ?vrtID meta:HasPathologicalProcess ?version .
}

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
SELECT DISTINCT ?x ?label

FROM <http://bioportal.bioontology.org/ontologies/SNOMEDCT>
WHERE
{
    
    ?x skos:prefLabel  ?label.
    FILTER regex(str(?label), "llerg")
}

# %%
# %endpoint http://localhost:8890/sparql
%endpoint http://sparql.bioontology.org/sparql
%display raw
%format json
%qparam apikey f9367108-21b4-4554-aa43-dee8fb7ccaea                             

%show all

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX snomed-term: <http://purl.bioontology.org/ontology/SNOMEDCT/>
PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT DISTINCT ?allergy_label ?allergy ?allergenic ?allergenic_label #?a
# SELECT DISTINCT ?a
# FROM <http://bioportal.bioontology.org/ontologies/SNOMEDCT>
WHERE
{   
    {
    service <http://sparql.bioontology.org/sparql>
        {
            {
                ?allergy rdfs:subClassOf snomed-term:419199007 .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
            union
            {
                ?allergy rdfs:subClassOf ?a.
                ?a rdfs:subClassOf snomed-term:419199007 .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
            union
            {
                ?allergy rdfs:subClassOf ?b .
                ?b rdfs:subClassOf ?a .
                ?a rdfs:subClassOf snomed-term:419199007 .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
            union
            {
                ?allergy rdfs:subClassOf ?c .
                ?c rdfs:subClassOf ?b .
                ?b rdfs:subClassOf ?a .
                ?a rdfs:subClassOf snomed-term:419199007 .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
            union
            {
                ?allergy rdfs:subClassOf ?d .
                ?d rdfs:subClassOf ?c .
                ?c rdfs:subClassOf ?b .
                ?b rdfs:subClassOf ?a .
                ?a rdfs:subClassOf snomed-term:419199007 .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
            union
            {
                ?allergy rdfs:subClassOf ?e .
                ?e rdfs:subClassOf ?d .
                ?d rdfs:subClassOf ?c .
                ?c rdfs:subClassOf ?b .
                ?b rdfs:subClassOf ?a .
                ?a rdfs:subClassOf snomed-term:419199007 .
                ?allergy <http://purl.bioontology.org/ontology/SNOMEDCT/has_causative_agent> ?allergenic .
                ?allergy skos:prefLabel ?allergy_label .
                ?allergenic skos:prefLabel ?allergenic_label.
            }
        }
    }
#     union
#     {
#         service <http://localhost:8890/sparql>
#         {
#             ?a food:IngredientListAsText ?ingredients .
#             ?a food:name ?name .
#             FILTER regex(lcase(str(?ingredients)), lcase(str(?allergenic_label)))
#             FILTER regex(lcase(str(?ingredients)), "pork")
#             FILTER regex(?ingredients, str(allergenic))
#             minus {?a food:IngredientListAsText ""}
#         }
#     } 
}

# %%
# %endpoint http://localhost:8890/sparql
 %endpoint http://sparql.bioontology.org/sparql

PREFIX food: <http://data.lirmm.fr/ontologies/food#>
PREFIX dbo: <http://dbpedia.org/ontology/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX dbpedia: <http://dbpedia.org/ontology/> 

SELECT *
WHERE {
    SERVICE <http://sparql.bioontology.org/sparql>
    {
        ?a ?b ?c .
    }
#     %endpoint http://sparql.bioontology.org/sparql
    SERVICE <http://localhost:8890/sparql>
    {
        ?a food:IngredientListAsText ?ingredients . 
#         ?a ?b ?ingredients . 
    } 
}
limit 100

# %%
%endpoint http://sparql.hegroup.org/sparql/
%display table
%show all

# %%
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
SELECT DISTINCT ?id ?label
WHERE {
    {?parent rdfs:subClassOf obo:FOODON_03411297} #animal food source
    UNION {?parent rdfs:subClassOf obo:FOODON_03411347} # plant food source
    UNION {?parent rdfs:subClassOf obo:FOODON_03470107} #preservation type
    ?id rdfs:subClassOf ?parent.
    ?id rdfs:label ?label
#     FILTER regex(str(?label), "food")
}
ORDER BY ?label

# %%
%endpoint http://sparql.hegroup.org/sparql/
%display table
%show all

SELECT DISTINCT ?property
WHERE {
  ?s ?property ?o .
}

# %%
%endpoint http://sparql.hegroup.org/sparql/

PREFIX dbo: <http://dbpedia.org/ontology/>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>

SELECT distinct ?id ?label ?art ?abstract
WHERE 
{ 
    {?parent rdfs:subClassOf obo:FOODON_03411297} #animal food source
#     UNION {?parent rdfs:subClassOf obo:FOODON_03411347} # plant food source
#     UNION {?parent rdfs:subClassOf obo:FOODON_03470107} #preservation type
    ?id rdfs:subClassOf ?parent.
    FILTER regex(str(?label), "food") 
        ?id rdfs:label ?label .
#     SERVICE <http://dbpedia.org/sparql?default-graph-uri=http://dbpedia.org> { ?art dbo:abstract ?abstract . }
}

# %%
%endpoint http://sparql.hegroup.org/sparql/

# %%
%endpoint http://sparql.hegroup.org/sparql/

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
SELECT DISTINCT ?id ?parent ?label ?definition
	WHERE {
		{?parent rdfs:subClassOf* obo:FOODON_03411297} #animal food source
		UNION {?parent rdfs:subClassOf* obo:FOODON_03411347} # plant food source
		UNION {?parent rdfs:subClassOf* obo:FOODON_03470107} #preservation type    

		?id rdfs:subClassOf ?parent.
		OPTIONAL {?id rdfs:label ?label}.
		OPTIONAL {?id obo:IAO_0000115 ?definition.}
	}
ORDER BY ?parent ?label ?uiLabel

# %%
%endpoint http://sparql.hegroup.org/sparql/

PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
SELECT DISTINCT ?ref ?refp ?label ?o ?p FROM <http://purl.obolibrary.org/obo/merged/FOODON> WHERE {
    ?ref ?refp ?o .
    FILTER ( ?refp IN ( owl:equivalentClass, rdfs:subClassOf ) ) .
    OPTIONAL { ?ref rdfs:label ?label } .
    {
        {
            SELECT ?s ?o FROM <http://purl.obolibrary.org/obo/merged/FOODON> WHERE {
                ?o ?p ?s .
            }
        }
        FILTER ( ?s= <http://purl.obolibrary.org/obo/FOODON_00002420> )
    }
}
ORDER BY ?label
limit 1000

# %%
%endpoint http://localhost:8890/sparql
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

SELECT ?subject ?predicate ?label
WHERE {
    <http://world-en.openfoodfacts.org/product/0011150584999/light-ice-cream-black-bing-cherry-roundy-s> ?predicate food:FoodProduct .
    ?subject ?predicate ?z
}

# %%
select distinct ?property ?obj where {
    <http://world-en.openfoodfacts.org/product/0011150584999/light-ice-cream-black-bing-cherry-roundy-s>  ?property ?obj . 
    
}

# %%
%endpoint http://localhost:8890/sparql
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

select distinct ?name ?ingredients where
{

    ?a food:IngredientListAsText ?ingredients .
    ?a food:name ?name .
    FILTER regex(str(?ingredients), "pork").
    minus {?a food:IngredientListAsText ""}
#     SERVICE <http://pt.dbpedia.org/sparql>
#    {
#       ?mun owl:sameAs ?dbp .
#       ?dbp rdfs:label ?name
#    }

}
limit 1000

# %%
%endpoint http://dydra.com/brunopenteado/br_municipalities/sparql
select * 
where 
{ 
   SERVICE <http://dydra.com/brunopenteado/br_municipalities/sparql>
   {
      ?mun owl:sameAs ?dbp .
      ?dbp rdfs:label ?name
   }

   SERVICE <http://pt.dbpedia.org/sparql>
   {
      ?mun owl:sameAs ?dbp .
      ?dbp rdfs:label ?name
   }
}

# %%
%endpoint http://localhost:8890/sparql
PREFIX food: <http://data.lirmm.fr/ontologies/food#>

select  ?b ?c where {
    <nodeID://b10018> ?b ?c 
    }
